# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ```
# As explained in the pdf, for this model we would like to classify regions 0,
# 3-4. To do so, we must make a dummy category, 5, that will blind regions 1-2 and 5-8.
#
# Since the label encoder needs consequetive categories, we will shift the non zero labels by 2. Showing the new maping values as:
#
# Original Category  --->    New Category
#       0            --->         0
#     1-2            --->         3
#       3            --->         1
#       4            --->         2
#     5-8            --->         3
#
# (Remeber '3' this a dummy category). This will be discarded when we merge
#                                     the output mask of all models. Into an NxNx9.
# ```

# %%
import os, glob
import matplotlib.pyplot as plt
import numpy as np
import pickle
import nibabel as nb
import matplotlib.image as mpimg
import cv2
import tensorflow as tf
from keras_preprocessing.image import ImageDataGenerator
from tensorflow import keras
from tensorflow.keras.utils import normalize
from tensorflow.keras.utils import to_categorical
from tqdm.notebook import tqdm 
from sys import getsizeof
from tensorflow.keras.models import load_model

import nibabel as nib

# %%
model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1f8a688cae5d> in <module>()
# ----> 1 model
#
# NameError: name 'model' is not defined

# %%
tf.keras.backend.clear_session()
del model

# %%
512/4
# Out:
# 128.0

# %%
# Define constants

# Path variables
data_dir = '/content/drive/Shareddrives/Banana Leaf Development/Data/Couinaud_Annotation_Data/'
data_dir_train_image = os.path.join(data_dir, 'complete_dataset/training/img:-1000:1000/img/')
data_dir_train_mask = os.path.join(data_dir,  'complete_dataset/training/couinaud/img/')

data_dir_test_image = os.path.join(data_dir, 'complete_dataset/testing/img:-1000:1000/img/')
data_dir_test_mask = os.path.join(data_dir, 'complete_dataset/testing/couinaud/img/')

data_dir_validate_image = os.path.join(data_dir, 'complete_dataset/validate/img:-1000:1000/img/')
data_dir_validate_mask = os.path.join(data_dir, 'complete_dataset/validate/couinaud/img/')

class_names = ['class_0','class_1','class_2','class_3',
               'class_4','class_5','class_6','class_7','class_8']

# Training variables
SEED = 7
BATCH_SIZE_TRAIN = 10
BATCH_SIZE_TEST = 10
BATCH_SIZE_VALIDATE = 10
NUM_TRAIN = 9288
NUM_TEST = 1042
NUM_VALIDATE = 1207

N_CLASSES = 4


# Image variables
IMAGE_HEIGHT = int(512/4)
IMAGE_WIDTH = int(512/4)
IMG_SIZE = (IMAGE_HEIGHT, IMAGE_WIDTH)


#Original Image size
OG_IMAGE_HEIGHT = 512
OG_IMAGE_WIDTH = 512
OG_IMG_SIZE = (OG_IMAGE_HEIGHT, OG_IMAGE_WIDTH)

NUM_EPOCH = 100

# %%
### Import the 'data' and save them in lists 

#Capture training image info as a list
#train_images = []
scaled_train_images = []

for index, img_path in tqdm(enumerate(sorted(glob.iglob(data_dir_train_image+ '*.png')))):
  substring = img_path[-5:]

  img = cv2.imread(img_path, 0)       
  #train_images.append(img)
  scaled_train_images.append(cv2.resize(img, IMG_SIZE, interpolation = cv2.INTER_LINEAR))

#Convert list to array for machine learning processing        
#train_images = np.array(train_images)
scaled_train_images = np.array(scaled_train_images)

print('##### TRAINING IMAGES #####')
#print(train_images.shape)
print(scaled_train_images.shape)
#print(type(train_images[0,0,0]))
##############################################################

#Capture mask/label info as a list
#train_masks = [] 
scaled_train_masks = []

for index, img_path in tqdm(enumerate(sorted(glob.iglob(data_dir_train_mask + '*.tif')))):
  substring = img_path[-5:]

  img = cv2.imread(img_path, 0)       
  #train_masks.append(img)
  other_mask_indices = (img != 0) & (img != 3) & (img != 4)
  img[other_mask_indices] = 5
  indices_all_but_0val = img > 0
  img[indices_all_but_0val] = img[indices_all_but_0val] - 2
  scaled_train_masks.append(cv2.resize(img, IMG_SIZE, interpolation = cv2.INTER_LINEAR))

#Convert list to array for machine learning processing      
#train_masks = np.array(train_masks)
scaled_train_masks = np.array(scaled_train_masks)

print('##### TRAINING MASKS #####') 
#print(train_masks.shape)
print(scaled_train_masks.shape)
#print(type(train_masks[0,0,0]))
##############################################################
##############################################################

#Capture validate image info as a list
#validate_images = []
scaled_validate_images = []

for index, img_path in tqdm(enumerate(sorted(glob.iglob(data_dir_validate_image+ '*.png')))):
  substring = img_path[-5:]

  img = cv2.imread(img_path, 0)       
  #validate_images.append(img)
  scaled_validate_images.append(cv2.resize(img, IMG_SIZE, interpolation = cv2.INTER_LINEAR))

#Convert list to array for machine learning processing        
#validate_images = np.array(validate_images)
scaled_validate_images = np.array(scaled_validate_images)

print('##### VALIDATE IMAGES #####')
#print(validate_images.shape)
print(scaled_validate_images.shape)
#print(type(validate_images[0,0,0]))
##############################################################

#Capture mask/label info as a list
#validate_masks = [] 
scaled_validate_masks = []

for index, img_path in tqdm(enumerate(sorted(glob.iglob(data_dir_validate_mask + '*.tif')))):
  substring = img_path[-5:]

  img = cv2.imread(img_path, 0)       
  #validate_masks.append(img)
  other_mask_indices = (img != 0) & (img != 3) & (img != 4)
  img[other_mask_indices] = 5
  indices_all_but_0val = img > 0
  img[indices_all_but_0val] = img[indices_all_but_0val] - 2
  scaled_validate_masks.append(cv2.resize(img, IMG_SIZE, interpolation = cv2.INTER_LINEAR))

#Convert list to array for machine learning processing      
#validate_masks = np.array(validate_masks)
scaled_validate_masks = np.array(scaled_validate_masks)

print('##### VALIDATE MASKS #####') 
#print(validate_masks.shape)
print(scaled_validate_masks.shape)
#print(type(validate_masks[0,0,0]))
##############################################################
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# ##### TRAINING IMAGES #####
# (9288, 128, 128)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# ##### TRAINING MASKS #####
# (9288, 128, 128)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# ##### VALIDATE IMAGES #####
# (1207, 128, 128)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# ##### VALIDATE MASKS #####
# (1207, 128, 128)

# %%
from sklearn.utils import shuffle
scaled_train_images, scaled_train_masks = shuffle(scaled_train_images,scaled_train_masks, random_state = SEED)

# %%
scaled_train_images.shape
# Out:
# (9288, 128, 128)

# %%
round(getsizeof(scaled_train_images) / 1024 / 1024 / 1024 ,2) #to get GB
# Out:
# 0.14

# %%
# np.unique(train_masks)

# %%
scaled_train_images = np.expand_dims(scaled_train_images, axis=3)
scaled_validate_images = np.expand_dims(scaled_validate_images, axis=3)


print('#### IMAGES ###')
# print(train_images.shape)
print(scaled_train_images.shape)
print(type(scaled_train_images[0,0,0,0]))

#print(validate_images.shape)
print(scaled_validate_images.shape)
print(type(scaled_validate_images[0,0,0,0]))

##########################################################################
scaled_train_masks = np.expand_dims(scaled_train_masks, axis=3)
scaled_validate_masks = np.expand_dims(scaled_validate_masks, axis=3)

print('#### MASKS ###')
#print(train_masks.shape)
print(scaled_train_masks.shape)

#print(validate_masks.shape)
print(scaled_validate_masks.shape)
# Out:
# #### IMAGES ###
# (9288, 128, 128, 1)
# <class 'numpy.uint8'>
# (1207, 128, 128, 1)
# <class 'numpy.uint8'>
# #### MASKS ###
# (9288, 128, 128, 1)
# (1207, 128, 128, 1)

# %%
#Encode labels for all masks
scaled_train_masks = to_categorical(scaled_train_masks, num_classes=N_CLASSES)
#print(train_masks.shape)
print(scaled_train_masks.shape)
# Out:
# (9288, 128, 128, 4)

# %%
round(getsizeof(scaled_train_images) / 1024 / 1024 / 1024 ,2) #to get GB
# Out:
# 0.0

# %%
scaled_validate_masks = to_categorical(scaled_validate_masks, num_classes=N_CLASSES)
#print(validate_masks.shape)
print(scaled_validate_masks.shape)
# Out:
# (1207, 128, 128, 4)

# %%
def display(display_list):
  plt.figure(figsize = (15,15))
  title = ['Input Image', 'True Mask', 'Predicted Mask', 'Predicted Mask \nw/ Threshold']

  for i in range(len(display_list)):
    plt.subplot(1, len(display_list), i+1)
    plt.title(title[i])
    plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]), cmap = 'Greys_r')
  plt.show()

# %%
def unet(n_levels, initial_features=32, n_blocks=2, kernel_size=3, pooling_size=2, in_channels=1, out_channels=1):
    inputs = keras.layers.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, in_channels))
    x = inputs
    
    convpars = dict(kernel_size=kernel_size, activation='relu', padding='same')
    
    #downstream
    skips = {}
    for level in range(n_levels):
        for _ in range(n_blocks):
            x = keras.layers.Conv2D(initial_features * 2 ** level, **convpars)(x)
        if level < n_levels - 1:
            skips[level] = x
            x = keras.layers.MaxPool2D(pooling_size)(x)
            
    # upstream
    for level in reversed(range(n_levels-1)):
        x = keras.layers.Conv2DTranspose(initial_features * 2 ** level, strides=pooling_size, **convpars)(x)
        x = keras.layers.Concatenate()([x, skips[level]])
        for _ in range(n_blocks):
            x = keras.layers.Conv2D(initial_features * 2 ** level, **convpars)(x)
            
    # output
    activation = 'sigmoid' if out_channels == 1 else 'softmax'
    x = keras.layers.Conv2D(out_channels, kernel_size=1, activation=activation, padding='same')(x)
    
    return keras.Model(inputs=[inputs], outputs=[x], name=f'UNET-L{n_levels}-F{initial_features}')

# %%
checkpoint_filepath = '/content/drive/Shareddrives/Banana Leaf Development/Data/Couinaud_Annotation_Data/model_notebooks/CompleteDataSet/4-Models:0-2,3-4,5-6,7-8/Model2'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='auto',
    save_best_only=True)

# %%
# Batches per epoch
EPOCH_STEP_TRAIN = NUM_TRAIN // BATCH_SIZE_TRAIN
EPOCH_STEP_TEST = NUM_TEST // BATCH_SIZE_TEST
EPOCH_STEP_VALIDATE = NUM_VALIDATE // BATCH_SIZE_VALIDATE

model = unet(n_levels= 4, out_channels=4)
#model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = [tf.keras.metrics.MeanIoU(num_classes=N_CLASSES)])
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
#model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = [dice_coef])
#model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = [soft_dice_loss])

# %%
model.summary()
# Out:
# Model: "UNET-L4-F32"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 128, 128, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 128, 128, 32) 9248        conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 64, 64, 32)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 64, 64, 64)   18496       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 64, 64, 64)   36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 128)  73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 128)  147584      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 256)  590080      conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 32, 32, 128)  295040      conv2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 256)  0           conv2d_transpose[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 128)  295040      concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 128)  147584      conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 64)   73792       conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 128)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 64)   36928       conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 32) 18464       conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 64) 0           conv2d_transpose_2[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 128, 128, 32) 18464       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 128, 32) 9248        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 4)  132         conv2d_13[0][0]
# ==================================================================================================
# Total params: 2,140,164
# Trainable params: 2,140,164
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit(scaled_train_images, scaled_train_masks, 
                    batch_size = BATCH_SIZE_TRAIN, 
                    steps_per_epoch=EPOCH_STEP_TRAIN,  
                    validation_data=(scaled_validate_images, scaled_validate_masks), 
                    validation_steps=EPOCH_STEP_VALIDATE,
                    epochs = NUM_EPOCH,
                    callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/100
# 928/928 [==============================] - 35s 19ms/step - loss: 0.2337 - accuracy: 0.9513 - val_loss: 0.0513 - val_accuracy: 0.9821
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/Banana Leaf Development/Data/Couinaud_Annotation_Data/model_notebooks/CompleteDataSet/4-Models:0-2,3-4,5-6,7-8/Model2/assets
# Epoch 2/100
# 928/928 [==============================] - 18s 19ms/step - loss: 0.0472 - accuracy: 0.9834 - val_loss: 0.0311 - val_accuracy: 0.9893
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/Banana Leaf Development/Data/Couinaud_Annotation_Data/model_notebooks/CompleteDataSet/4-Models:0-2,3-4,5-6,7-8/Model2/assets
# Epoch 3/100
# 928/928 [==============================] - 17s 18ms/step - loss: 0.0290 - accuracy: 0.9899 - val_loss: 0.0237 - val_accuracy: 0.9915
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/Banana Leaf Development/Data/Couinaud_Annotation_Data/model_notebooks/CompleteDataSet/4-Models:0-2,3-4,5-6,7-8/Model2/assets
# Epoch 4/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0219 - accuracy: 0.9924 - val_loss: 0.0249 - val_accuracy: 0.9913
# Epoch 5/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0181 - accuracy: 0.9935 - val_loss: 0.0234 - val_accuracy: 0.9923
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/Banana Leaf Development/Data/Couinaud_Annotation_Data/model_notebooks/CompleteDataSet/4-Models:0-2,3-4,5-6,7-8/Model2/assets
# Epoch 6/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0173 - accuracy: 0.9939 - val_loss: 0.0255 - val_accuracy: 0.9917
# Epoch 7/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0147 - accuracy: 0.9947 - val_loss: 0.0227 - val_accuracy: 0.9923
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/Banana Leaf Development/Data/Couinaud_Annotation_Data/model_notebooks/CompleteDataSet/4-Models:0-2,3-4,5-6,7-8/Model2/assets
# Epoch 8/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0128 - accuracy: 0.9954 - val_loss: 0.0287 - val_accuracy: 0.9905
# Epoch 9/100
# 928/928 [==============================] - 17s 18ms/step - loss: 0.0142 - accuracy: 0.9949 - val_loss: 0.0219 - val_accuracy: 0.9925
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/Banana Leaf Development/Data/Couinaud_Annotation_Data/model_notebooks/CompleteDataSet/4-Models:0-2,3-4,5-6,7-8/Model2/assets
# Epoch 10/100
# 928/928 [==============================] - 17s 18ms/step - loss: 0.0111 - accuracy: 0.9960 - val_loss: 0.0255 - val_accuracy: 0.9922
# Epoch 11/100
# 928/928 [==============================] - 17s 18ms/step - loss: 0.0112 - accuracy: 0.9959 - val_loss: 0.0243 - val_accuracy: 0.9922
# Epoch 12/100
# 928/928 [==============================] - 17s 18ms/step - loss: 0.0101 - accuracy: 0.9963 - val_loss: 0.0230 - val_accuracy: 0.9931
# Epoch 13/100
# 928/928 [==============================] - 17s 18ms/step - loss: 0.0106 - accuracy: 0.9962 - val_loss: 0.0245 - val_accuracy: 0.9927
# Epoch 14/100
# 928/928 [==============================] - 17s 18ms/step - loss: 0.0094 - accuracy: 0.9966 - val_loss: 0.0265 - val_accuracy: 0.9927
# Epoch 15/100
# 928/928 [==============================] - 17s 18ms/step - loss: 0.0091 - accuracy: 0.9967 - val_loss: 0.0245 - val_accuracy: 0.9926
# Epoch 16/100
# 928/928 [==============================] - 17s 18ms/step - loss: 0.0088 - accuracy: 0.9968 - val_loss: 0.0277 - val_accuracy: 0.9915
# Epoch 17/100
# 928/928 [==============================] - 17s 18ms/step - loss: 0.0099 - accuracy: 0.9964 - val_loss: 0.0259 - val_accuracy: 0.9925
# Epoch 18/100
# 928/928 [==============================] - 17s 18ms/step - loss: 0.0081 - accuracy: 0.9970 - val_loss: 0.0252 - val_accuracy: 0.9931
# Epoch 19/100
# 928/928 [==============================] - 17s 18ms/step - loss: 0.0077 - accuracy: 0.9971 - val_loss: 0.0276 - val_accuracy: 0.9919
# Epoch 20/100
# 928/928 [==============================] - 17s 18ms/step - loss: 0.0091 - accuracy: 0.9967 - val_loss: 0.0268 - val_accuracy: 0.9930
# Epoch 21/100
# 928/928 [==============================] - 17s 18ms/step - loss: 0.0081 - accuracy: 0.9970 - val_loss: 0.0258 - val_accuracy: 0.9932
# Epoch 22/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0070 - accuracy: 0.9974 - val_loss: 0.0284 - val_accuracy: 0.9924
# Epoch 23/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0089 - accuracy: 0.9968 - val_loss: 0.0300 - val_accuracy: 0.9928
# Epoch 24/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0069 - accuracy: 0.9974 - val_loss: 0.0251 - val_accuracy: 0.9933
# Epoch 25/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0082 - accuracy: 0.9970 - val_loss: 0.0260 - val_accuracy: 0.9934
# Epoch 26/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 0.0296 - val_accuracy: 0.9931
# Epoch 27/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0069 - accuracy: 0.9974 - val_loss: 0.0286 - val_accuracy: 0.9927
# Epoch 28/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0068 - accuracy: 0.9975 - val_loss: 0.0252 - val_accuracy: 0.9934
# Epoch 29/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0064 - accuracy: 0.9976 - val_loss: 0.0277 - val_accuracy: 0.9933
# Epoch 30/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0072 - accuracy: 0.9973 - val_loss: 0.0304 - val_accuracy: 0.9926
# Epoch 31/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0085 - accuracy: 0.9970 - val_loss: 0.0282 - val_accuracy: 0.9926
# Epoch 32/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0075 - accuracy: 0.9973 - val_loss: 0.0289 - val_accuracy: 0.9927
# Epoch 33/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0064 - accuracy: 0.9976 - val_loss: 0.0289 - val_accuracy: 0.9931
# Epoch 34/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0065 - accuracy: 0.9976 - val_loss: 0.0278 - val_accuracy: 0.9935
# Epoch 35/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0060 - accuracy: 0.9977 - val_loss: 0.0269 - val_accuracy: 0.9921
# Epoch 36/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0071 - accuracy: 0.9974 - val_loss: 0.0322 - val_accuracy: 0.9927
# Epoch 37/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0063 - accuracy: 0.9976 - val_loss: 0.0311 - val_accuracy: 0.9932
# Epoch 38/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.0307 - val_accuracy: 0.9927
# Epoch 39/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0064 - accuracy: 0.9976 - val_loss: 0.0287 - val_accuracy: 0.9930
# Epoch 40/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0058 - accuracy: 0.9978 - val_loss: 0.0314 - val_accuracy: 0.9929
# Epoch 41/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0063 - accuracy: 0.9976 - val_loss: 0.0265 - val_accuracy: 0.9924
# Epoch 42/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 0.0286 - val_accuracy: 0.9932
# Epoch 43/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0063 - accuracy: 0.9976 - val_loss: 0.0300 - val_accuracy: 0.9921
# Epoch 44/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0079 - accuracy: 0.9971 - val_loss: 0.0302 - val_accuracy: 0.9929
# Epoch 45/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0064 - accuracy: 0.9976 - val_loss: 0.0316 - val_accuracy: 0.9929
# Epoch 46/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0063 - accuracy: 0.9976 - val_loss: 0.0335 - val_accuracy: 0.9927
# Epoch 47/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0063 - accuracy: 0.9977 - val_loss: 0.0324 - val_accuracy: 0.9929
# Epoch 48/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0064 - accuracy: 0.9976 - val_loss: 0.0307 - val_accuracy: 0.9933
# Epoch 49/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0057 - accuracy: 0.9978 - val_loss: 0.0307 - val_accuracy: 0.9930
# Epoch 50/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0061 - accuracy: 0.9977 - val_loss: 0.0295 - val_accuracy: 0.9924
# Epoch 51/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.0285 - val_accuracy: 0.9929
# Epoch 52/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0058 - accuracy: 0.9978 - val_loss: 0.0284 - val_accuracy: 0.9929
# Epoch 53/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.0300 - val_accuracy: 0.9933
# Epoch 54/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 0.0327 - val_accuracy: 0.9932
# Epoch 55/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0056 - accuracy: 0.9979 - val_loss: 0.0321 - val_accuracy: 0.9930
# Epoch 56/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.0318 - val_accuracy: 0.9909
# Epoch 57/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.0286 - val_accuracy: 0.9931
# Epoch 58/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.0279 - val_accuracy: 0.9924
# Epoch 59/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0069 - accuracy: 0.9975 - val_loss: 0.0298 - val_accuracy: 0.9932
# Epoch 60/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.0281 - val_accuracy: 0.9933
# Epoch 61/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.0308 - val_accuracy: 0.9930
# Epoch 62/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0061 - accuracy: 0.9977 - val_loss: 0.0315 - val_accuracy: 0.9930
# Epoch 63/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0064 - accuracy: 0.9976 - val_loss: 0.0279 - val_accuracy: 0.9933
# Epoch 64/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0060 - accuracy: 0.9977 - val_loss: 0.0276 - val_accuracy: 0.9930
# Epoch 65/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.0287 - val_accuracy: 0.9930
# Epoch 66/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0060 - accuracy: 0.9977 - val_loss: 0.0291 - val_accuracy: 0.9930
# Epoch 67/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0056 - accuracy: 0.9979 - val_loss: 0.0290 - val_accuracy: 0.9931
# Epoch 68/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 0.0324 - val_accuracy: 0.9930
# Epoch 69/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0055 - accuracy: 0.9979 - val_loss: 0.0318 - val_accuracy: 0.9933
# Epoch 70/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0058 - accuracy: 0.9978 - val_loss: 0.0307 - val_accuracy: 0.9931
# Epoch 71/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0077 - accuracy: 0.9973 - val_loss: 0.0297 - val_accuracy: 0.9932
# Epoch 72/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0058 - accuracy: 0.9978 - val_loss: 0.0314 - val_accuracy: 0.9932
# Epoch 73/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0052 - accuracy: 0.9980 - val_loss: 0.0295 - val_accuracy: 0.9929
# Epoch 74/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0055 - accuracy: 0.9979 - val_loss: 0.0338 - val_accuracy: 0.9916
# Epoch 75/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.0312 - val_accuracy: 0.9933
# Epoch 76/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0056 - accuracy: 0.9979 - val_loss: 0.0339 - val_accuracy: 0.9927
# Epoch 77/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.0361 - val_accuracy: 0.9927
# Epoch 78/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 0.0303 - val_accuracy: 0.9930
# Epoch 79/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0062 - accuracy: 0.9977 - val_loss: 0.0288 - val_accuracy: 0.9924
# Epoch 80/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0065 - accuracy: 0.9976 - val_loss: 0.0300 - val_accuracy: 0.9930
# Epoch 81/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0071 - accuracy: 0.9974 - val_loss: 0.0305 - val_accuracy: 0.9929
# Epoch 82/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0056 - accuracy: 0.9979 - val_loss: 0.0311 - val_accuracy: 0.9929
# Epoch 83/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 0.0328 - val_accuracy: 0.9931
# Epoch 84/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0052 - accuracy: 0.9980 - val_loss: 0.0353 - val_accuracy: 0.9930
# Epoch 85/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0051 - accuracy: 0.9981 - val_loss: 0.0309 - val_accuracy: 0.9930
# Epoch 86/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.0312 - val_accuracy: 0.9931
# Epoch 87/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0061 - accuracy: 0.9977 - val_loss: 0.0333 - val_accuracy: 0.9928
# Epoch 88/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.0335 - val_accuracy: 0.9930
# Epoch 89/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0056 - accuracy: 0.9979 - val_loss: 0.0289 - val_accuracy: 0.9928
# Epoch 90/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0056 - accuracy: 0.9979 - val_loss: 0.0316 - val_accuracy: 0.9931
# Epoch 91/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.0315 - val_accuracy: 0.9921
# Epoch 92/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0068 - accuracy: 0.9975 - val_loss: 0.0327 - val_accuracy: 0.9929
# Epoch 93/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 0.0319 - val_accuracy: 0.9932
# Epoch 94/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0050 - accuracy: 0.9981 - val_loss: 0.0333 - val_accuracy: 0.9932
# Epoch 95/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0050 - accuracy: 0.9981 - val_loss: 0.0353 - val_accuracy: 0.9931
# Epoch 96/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0055 - accuracy: 0.9979 - val_loss: 0.0290 - val_accuracy: 0.9917
# Epoch 97/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0074 - accuracy: 0.9974 - val_loss: 0.0316 - val_accuracy: 0.9929
# Epoch 98/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0060 - accuracy: 0.9978 - val_loss: 0.0330 - val_accuracy: 0.9929
# Epoch 99/100
# 928/928 [==============================] - 17s 19ms/step - loss: 0.0057 - accuracy: 0.9978 - val_loss: 0.0355 - val_accuracy: 0.9930
# Epoch 100/100
# 928/928 [==============================] - 17s 18ms/step - loss: 0.0052 - accuracy: 0.9980 - val_loss: 0.0324 - val_accuracy: 0.9933

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'g', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.vlines(9, 0, 0.12, colors = 'b', linestyles = 'dashed', label='Saved Best Model') # We can see from the training history above that
                                                      # best model was saved at epoch 5
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(linestyle='-')
plt.show()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'g', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.vlines(9, 0.965, 1, colors = 'b', linestyles = 'dashed', label='Saved Best Model') # We can see from the training history above that
                                                      # best model was saved at epoch 5
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(linestyle='-')
plt.show()

# %%
tf.keras.backend.clear_session()
del model
del model2 
del imported_model

# %%
tf.keras.backend.clear_session()
del imported_model
