# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ```
# As explained in the pdf, for this model we would like to classify regions 0,
# 7-8. To do so, we must make a dummy category, 9, that will blind regions 1-6.
#
# Since the label encoder needs consequetive categories, we will shift the non zero labels by 6. Showing the new maping values as:
#
# Original Category  --->    New Category
#       0            --->         0
#     1-6            --->         3
#       7            --->         1
#       8            --->         2
#
# (Remeber '3' this a dummy category). This will be discarded when we merge
#                                     the output mask of all models. Into an NxNx9.
# ```

# %%
import os, glob
import matplotlib.pyplot as plt
import numpy as np
import pickle
import nibabel as nb
import matplotlib.image as mpimg
import cv2
import tensorflow as tf
from keras_preprocessing.image import ImageDataGenerator
from tensorflow import keras
from tensorflow.keras.utils import normalize
from tensorflow.keras.utils import to_categorical
from tqdm.notebook import tqdm 
from sys import getsizeof
from tensorflow.keras.models import load_model

import nibabel as nib

# %%
model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1f8a688cae5d> in <module>()
# ----> 1 model
#
# NameError: name 'model' is not defined

# %%
tf.keras.backend.clear_session()
del model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-669161fd7eba> in <module>()
#       1 tf.keras.backend.clear_session()
# ----> 2 del model
#
# NameError: name 'model' is not defined

# %%
512/4
# Out:
# 128.0

# %%
# Define constants

# Path variables
data_dir = '/content/drive/Shareddrives/Banana Leaf Development/Data/Couinaud_Annotation_Data/'
data_dir_train_image = os.path.join(data_dir, 'complete_dataset/training/img:-1000:1000/img/')
data_dir_train_mask = os.path.join(data_dir,  'complete_dataset/training/couinaud/img/')

data_dir_test_image = os.path.join(data_dir, 'complete_dataset/testing/img:-1000:1000/img/')
data_dir_test_mask = os.path.join(data_dir, 'complete_dataset/testing/couinaud/img/')

data_dir_validate_image = os.path.join(data_dir, 'complete_dataset/validate/img:-1000:1000/img/')
data_dir_validate_mask = os.path.join(data_dir, 'complete_dataset/validate/couinaud/img/')

class_names = ['class_0','class_1','class_2','class_3',
               'class_4','class_5','class_6','class_7','class_8']

# Training variables
SEED = 7
BATCH_SIZE_TRAIN = 10
BATCH_SIZE_TEST = 10
BATCH_SIZE_VALIDATE = 10
NUM_TRAIN = 9288
NUM_TEST = 1042
NUM_VALIDATE = 1207

N_CLASSES = 4


# Image variables
IMAGE_HEIGHT = int(512/4)
IMAGE_WIDTH = int(512/4)
IMG_SIZE = (IMAGE_HEIGHT, IMAGE_WIDTH)


#Original Image size
OG_IMAGE_HEIGHT = 512
OG_IMAGE_WIDTH = 512
OG_IMG_SIZE = (OG_IMAGE_HEIGHT, OG_IMAGE_WIDTH)

NUM_EPOCH = 100

# %%
### Import the 'data' and save them in lists 

#Capture training image info as a list
#train_images = []
scaled_train_images = []

for index, img_path in tqdm(enumerate(sorted(glob.iglob(data_dir_train_image+ '*.png')))):
  substring = img_path[-5:]

  img = cv2.imread(img_path, 0)       
  #train_images.append(img)
  scaled_train_images.append(cv2.resize(img, IMG_SIZE, interpolation = cv2.INTER_LINEAR))

#Convert list to array for machine learning processing        
#train_images = np.array(train_images)
scaled_train_images = np.array(scaled_train_images)

print('##### TRAINING IMAGES #####')
#print(train_images.shape)
print(scaled_train_images.shape)
#print(type(train_images[0,0,0]))
##############################################################

#Capture mask/label info as a list
#train_masks = [] 
scaled_train_masks = []

for index, img_path in tqdm(enumerate(sorted(glob.iglob(data_dir_train_mask + '*.tif')))):
  substring = img_path[-5:]

  img = cv2.imread(img_path, 0)       
  #train_masks.append(img)
  other_mask_indices = (img != 0) & (img != 7) & (img != 8)
  img[other_mask_indices] = 9
  indices_all_but_0val = img > 0
  img[indices_all_but_0val] = img[indices_all_but_0val] - 6
  scaled_train_masks.append(cv2.resize(img, IMG_SIZE, interpolation = cv2.INTER_LINEAR))

#Convert list to array for machine learning processing      
#train_masks = np.array(train_masks)
scaled_train_masks = np.array(scaled_train_masks)

print('##### TRAINING MASKS #####') 
#print(train_masks.shape)
print(scaled_train_masks.shape)
#print(type(train_masks[0,0,0]))
##############################################################
##############################################################

#Capture validate image info as a list
#validate_images = []
scaled_validate_images = []

for index, img_path in tqdm(enumerate(sorted(glob.iglob(data_dir_validate_image+ '*.png')))):
  substring = img_path[-5:]

  img = cv2.imread(img_path, 0)       
  #validate_images.append(img)
  scaled_validate_images.append(cv2.resize(img, IMG_SIZE, interpolation = cv2.INTER_LINEAR))

#Convert list to array for machine learning processing        
#validate_images = np.array(validate_images)
scaled_validate_images = np.array(scaled_validate_images)

print('##### VALIDATE IMAGES #####')
#print(validate_images.shape)
print(scaled_validate_images.shape)
#print(type(validate_images[0,0,0]))
##############################################################

#Capture mask/label info as a list
#validate_masks = [] 
scaled_validate_masks = []

for index, img_path in tqdm(enumerate(sorted(glob.iglob(data_dir_validate_mask + '*.tif')))):
  substring = img_path[-5:]

  img = cv2.imread(img_path, 0)       
  #validate_masks.append(img)
  other_mask_indices = (img != 0) & (img != 7) & (img != 8)
  img[other_mask_indices] = 9
  indices_all_but_0val = img > 0
  img[indices_all_but_0val] = img[indices_all_but_0val] - 6
  scaled_validate_masks.append(cv2.resize(img, IMG_SIZE, interpolation = cv2.INTER_LINEAR))

#Convert list to array for machine learning processing      
#validate_masks = np.array(validate_masks)
scaled_validate_masks = np.array(scaled_validate_masks)

print('##### VALIDATE MASKS #####') 
#print(validate_masks.shape)
print(scaled_validate_masks.shape)
#print(type(validate_masks[0,0,0]))
##############################################################
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# ##### TRAINING IMAGES #####
# (9288, 128, 128)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# ##### TRAINING MASKS #####
# (9288, 128, 128)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# ##### VALIDATE IMAGES #####
# (1207, 128, 128)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# ##### VALIDATE MASKS #####
# (1207, 128, 128)

# %%
from sklearn.utils import shuffle
scaled_train_images, scaled_train_masks = shuffle(scaled_train_images,scaled_train_masks, random_state = SEED)

# %%
scaled_train_images.shape
# Out:
# (9288, 128, 128)

# %%
round(getsizeof(scaled_train_images) / 1024 / 1024 / 1024 ,2) #to get GB
# Out:
# 0.14

# %%
# np.unique(train_masks)

# %%
scaled_train_images = np.expand_dims(scaled_train_images, axis=3)
scaled_validate_images = np.expand_dims(scaled_validate_images, axis=3)


print('#### IMAGES ###')
# print(train_images.shape)
print(scaled_train_images.shape)
print(type(scaled_train_images[0,0,0,0]))

#print(validate_images.shape)
print(scaled_validate_images.shape)
print(type(scaled_validate_images[0,0,0,0]))

##########################################################################
scaled_train_masks = np.expand_dims(scaled_train_masks, axis=3)
scaled_validate_masks = np.expand_dims(scaled_validate_masks, axis=3)

print('#### MASKS ###')
#print(train_masks.shape)
print(scaled_train_masks.shape)

#print(validate_masks.shape)
print(scaled_validate_masks.shape)
# Out:
# #### IMAGES ###
# (9288, 128, 128, 1)
# <class 'numpy.uint8'>
# (1207, 128, 128, 1)
# <class 'numpy.uint8'>
# #### MASKS ###
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e515a315b21e> in <module>()
#      17
#      18 print('#### MASKS ###')
# ---> 19 print(train_masks.shape)
#      20 print(scaled_train_masks.shape)
#      21
#
# NameError: name 'train_masks' is not defined

# %%
#Encode labels for all masks
scaled_train_masks = to_categorical(scaled_train_masks, num_classes=N_CLASSES)
#print(train_masks.shape)
print(scaled_train_masks.shape)
# Out:
# (9288, 128, 128, 4)

# %%
round(getsizeof(scaled_train_images) / 1024 / 1024 / 1024 ,2) #to get GB

# %%
scaled_validate_masks = to_categorical(scaled_validate_masks, num_classes=N_CLASSES)
#print(validate_masks.shape)
print(scaled_validate_masks.shape)
# Out:
# (1207, 128, 128, 4)

# %%
def display(display_list):
  plt.figure(figsize = (15,15))
  title = ['Input Image', 'True Mask', 'Predicted Mask', 'Predicted Mask \nw/ Threshold']

  for i in range(len(display_list)):
    plt.subplot(1, len(display_list), i+1)
    plt.title(title[i])
    plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]), cmap = 'Greys_r')
  plt.show()

# %%
def unet(n_levels, initial_features=32, n_blocks=2, kernel_size=3, pooling_size=2, in_channels=1, out_channels=1):
    inputs = keras.layers.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, in_channels))
    x = inputs
    
    convpars = dict(kernel_size=kernel_size, activation='relu', padding='same')
    
    #downstream
    skips = {}
    for level in range(n_levels):
        for _ in range(n_blocks):
            x = keras.layers.Conv2D(initial_features * 2 ** level, **convpars)(x)
        if level < n_levels - 1:
            skips[level] = x
            x = keras.layers.MaxPool2D(pooling_size)(x)
            
    # upstream
    for level in reversed(range(n_levels-1)):
        x = keras.layers.Conv2DTranspose(initial_features * 2 ** level, strides=pooling_size, **convpars)(x)
        x = keras.layers.Concatenate()([x, skips[level]])
        for _ in range(n_blocks):
            x = keras.layers.Conv2D(initial_features * 2 ** level, **convpars)(x)
            
    # output
    activation = 'sigmoid' if out_channels == 1 else 'softmax'
    x = keras.layers.Conv2D(out_channels, kernel_size=1, activation=activation, padding='same')(x)
    
    return keras.Model(inputs=[inputs], outputs=[x], name=f'UNET-L{n_levels}-F{initial_features}')

# %%
checkpoint_filepath = '/content/drive/Shareddrives/Banana Leaf Development/Data/Couinaud_Annotation_Data/model_notebooks/CompleteDataSet/4-Models:0-2,3-4,5-6,7-8/Model4'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_loss',
    mode='auto',
    save_best_only=True)

# %%
# Batches per epoch
EPOCH_STEP_TRAIN = NUM_TRAIN // BATCH_SIZE_TRAIN
EPOCH_STEP_TEST = NUM_TEST // BATCH_SIZE_TEST
EPOCH_STEP_VALIDATE = NUM_VALIDATE // BATCH_SIZE_VALIDATE

model = unet(n_levels= 4, out_channels=4)
#model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = [tf.keras.metrics.MeanIoU(num_classes=N_CLASSES)])
model.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
#model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = [dice_coef])
#model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = [soft_dice_loss])

# %%
model.summary()

# %%
history = model.fit(scaled_train_images, scaled_train_masks, 
                    batch_size = BATCH_SIZE_TRAIN, 
                    steps_per_epoch=EPOCH_STEP_TRAIN,  
                    validation_data=(scaled_validate_images, scaled_validate_masks), 
                    validation_steps=EPOCH_STEP_VALIDATE,
                    epochs = NUM_EPOCH,
                    callbacks=[model_checkpoint_callback])
# Out:
# Epoch 1/100
# 928/928 [==============================] - 44s 29ms/step - loss: 0.2835 - accuracy: 0.9400 - val_loss: 0.0747 - val_accuracy: 0.9718
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/Banana Leaf Development/Data/Couinaud_Annotation_Data/model_notebooks/CompleteDataSet/4-Models:0-2,3-4,5-6,7-8/Model4/assets
# Epoch 2/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0732 - accuracy: 0.9736 - val_loss: 0.0540 - val_accuracy: 0.9803
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/Banana Leaf Development/Data/Couinaud_Annotation_Data/model_notebooks/CompleteDataSet/4-Models:0-2,3-4,5-6,7-8/Model4/assets
# Epoch 3/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0425 - accuracy: 0.9849 - val_loss: 0.0369 - val_accuracy: 0.9870
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/Banana Leaf Development/Data/Couinaud_Annotation_Data/model_notebooks/CompleteDataSet/4-Models:0-2,3-4,5-6,7-8/Model4/assets
# Epoch 4/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0319 - accuracy: 0.9886 - val_loss: 0.0304 - val_accuracy: 0.9893
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/Banana Leaf Development/Data/Couinaud_Annotation_Data/model_notebooks/CompleteDataSet/4-Models:0-2,3-4,5-6,7-8/Model4/assets
# Epoch 5/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0262 - accuracy: 0.9906 - val_loss: 0.0288 - val_accuracy: 0.9899
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/Banana Leaf Development/Data/Couinaud_Annotation_Data/model_notebooks/CompleteDataSet/4-Models:0-2,3-4,5-6,7-8/Model4/assets
# Epoch 6/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0222 - accuracy: 0.9920 - val_loss: 0.0285 - val_accuracy: 0.9901
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/Banana Leaf Development/Data/Couinaud_Annotation_Data/model_notebooks/CompleteDataSet/4-Models:0-2,3-4,5-6,7-8/Model4/assets
# Epoch 7/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0199 - accuracy: 0.9928 - val_loss: 0.0298 - val_accuracy: 0.9902
# Epoch 8/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0186 - accuracy: 0.9934 - val_loss: 0.0292 - val_accuracy: 0.9906
# Epoch 9/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0214 - accuracy: 0.9927 - val_loss: 0.0303 - val_accuracy: 0.9908
# Epoch 10/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0138 - accuracy: 0.9950 - val_loss: 0.0302 - val_accuracy: 0.9901
# Epoch 11/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0137 - accuracy: 0.9951 - val_loss: 0.0337 - val_accuracy: 0.9912
# Epoch 12/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0130 - accuracy: 0.9953 - val_loss: 0.0338 - val_accuracy: 0.9912
# Epoch 13/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0110 - accuracy: 0.9960 - val_loss: 0.0344 - val_accuracy: 0.9918
# Epoch 14/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0111 - accuracy: 0.9960 - val_loss: 0.0354 - val_accuracy: 0.9903
# Epoch 15/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0121 - accuracy: 0.9958 - val_loss: 0.0335 - val_accuracy: 0.9910
# Epoch 16/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0099 - accuracy: 0.9964 - val_loss: 0.0342 - val_accuracy: 0.9909
# Epoch 17/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0091 - accuracy: 0.9967 - val_loss: 0.0350 - val_accuracy: 0.9903
# Epoch 18/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0110 - accuracy: 0.9961 - val_loss: 0.0333 - val_accuracy: 0.9887
# Epoch 19/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0092 - accuracy: 0.9967 - val_loss: 0.0321 - val_accuracy: 0.9903
# Epoch 20/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0100 - accuracy: 0.9964 - val_loss: 0.0331 - val_accuracy: 0.9916
# Epoch 21/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0085 - accuracy: 0.9969 - val_loss: 0.0354 - val_accuracy: 0.9902
# Epoch 22/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0095 - accuracy: 0.9966 - val_loss: 0.0350 - val_accuracy: 0.9916
# Epoch 23/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0092 - accuracy: 0.9967 - val_loss: 0.0372 - val_accuracy: 0.9916
# Epoch 24/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0085 - accuracy: 0.9969 - val_loss: 0.0357 - val_accuracy: 0.9917
# Epoch 25/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0078 - accuracy: 0.9971 - val_loss: 0.0348 - val_accuracy: 0.9918
# Epoch 26/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 0.0429 - val_accuracy: 0.9899
# Epoch 27/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0085 - accuracy: 0.9969 - val_loss: 0.0365 - val_accuracy: 0.9923
# Epoch 28/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.0357 - val_accuracy: 0.9909
# Epoch 29/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0087 - accuracy: 0.9969 - val_loss: 0.0308 - val_accuracy: 0.9911
# Epoch 30/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 0.0322 - val_accuracy: 0.9916
# Epoch 31/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.0349 - val_accuracy: 0.9914
# Epoch 32/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0074 - accuracy: 0.9973 - val_loss: 0.0412 - val_accuracy: 0.9918
# Epoch 33/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0068 - accuracy: 0.9975 - val_loss: 0.0397 - val_accuracy: 0.9916
# Epoch 34/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0077 - accuracy: 0.9972 - val_loss: 0.0413 - val_accuracy: 0.9914
# Epoch 35/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0094 - accuracy: 0.9967 - val_loss: 0.0405 - val_accuracy: 0.9914
# Epoch 36/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0077 - accuracy: 0.9972 - val_loss: 0.0349 - val_accuracy: 0.9916
# Epoch 37/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0069 - accuracy: 0.9975 - val_loss: 0.0416 - val_accuracy: 0.9918
# Epoch 38/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0064 - accuracy: 0.9976 - val_loss: 0.0393 - val_accuracy: 0.9919
# Epoch 39/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0061 - accuracy: 0.9977 - val_loss: 0.0390 - val_accuracy: 0.9915
# Epoch 40/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0067 - accuracy: 0.9975 - val_loss: 0.0396 - val_accuracy: 0.9919
# Epoch 41/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0083 - accuracy: 0.9971 - val_loss: 0.0347 - val_accuracy: 0.9919
# Epoch 42/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.0420 - val_accuracy: 0.9908
# Epoch 43/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0070 - accuracy: 0.9975 - val_loss: 0.0379 - val_accuracy: 0.9921
# Epoch 44/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0060 - accuracy: 0.9978 - val_loss: 0.0383 - val_accuracy: 0.9920
# Epoch 45/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0077 - accuracy: 0.9973 - val_loss: 0.0375 - val_accuracy: 0.9915
# Epoch 46/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0073 - accuracy: 0.9974 - val_loss: 0.0354 - val_accuracy: 0.9917
# Epoch 47/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.0416 - val_accuracy: 0.9920
# Epoch 48/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0058 - accuracy: 0.9978 - val_loss: 0.0408 - val_accuracy: 0.9920
# Epoch 49/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0081 - accuracy: 0.9971 - val_loss: 0.0361 - val_accuracy: 0.9907
# Epoch 50/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0079 - accuracy: 0.9972 - val_loss: 0.0354 - val_accuracy: 0.9917
# Epoch 51/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0061 - accuracy: 0.9977 - val_loss: 0.0392 - val_accuracy: 0.9924
# Epoch 52/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.0429 - val_accuracy: 0.9921
# Epoch 53/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.0420 - val_accuracy: 0.9907
# Epoch 54/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0100 - accuracy: 0.9966 - val_loss: 0.0382 - val_accuracy: 0.9921
# Epoch 55/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0069 - accuracy: 0.9975 - val_loss: 0.0383 - val_accuracy: 0.9920
# Epoch 56/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.0413 - val_accuracy: 0.9921
# Epoch 57/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 0.0432 - val_accuracy: 0.9918
# Epoch 58/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0061 - accuracy: 0.9977 - val_loss: 0.0350 - val_accuracy: 0.9917
# Epoch 59/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0069 - accuracy: 0.9975 - val_loss: 0.0373 - val_accuracy: 0.9919
# Epoch 60/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.0405 - val_accuracy: 0.9921
# Epoch 61/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0056 - accuracy: 0.9979 - val_loss: 0.0385 - val_accuracy: 0.9917
# Epoch 62/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0065 - accuracy: 0.9976 - val_loss: 0.0356 - val_accuracy: 0.9919
# Epoch 63/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 0.0396 - val_accuracy: 0.9919
# Epoch 64/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.0390 - val_accuracy: 0.9921
# Epoch 65/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.0428 - val_accuracy: 0.9920
# Epoch 66/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0054 - accuracy: 0.9979 - val_loss: 0.0460 - val_accuracy: 0.9919
# Epoch 67/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.0459 - val_accuracy: 0.9914
# Epoch 68/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0060 - accuracy: 0.9978 - val_loss: 0.0395 - val_accuracy: 0.9913
# Epoch 69/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 0.0400 - val_accuracy: 0.9919
# Epoch 70/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0066 - accuracy: 0.9976 - val_loss: 0.0397 - val_accuracy: 0.9922
# Epoch 71/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.0437 - val_accuracy: 0.9922
# Epoch 72/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.0410 - val_accuracy: 0.9920
# Epoch 73/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0055 - accuracy: 0.9979 - val_loss: 0.0376 - val_accuracy: 0.9919
# Epoch 74/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0064 - accuracy: 0.9976 - val_loss: 0.0425 - val_accuracy: 0.9921
# Epoch 75/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0056 - accuracy: 0.9979 - val_loss: 0.0384 - val_accuracy: 0.9920
# Epoch 76/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0056 - accuracy: 0.9979 - val_loss: 0.0453 - val_accuracy: 0.9921
# Epoch 77/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0055 - accuracy: 0.9979 - val_loss: 0.0418 - val_accuracy: 0.9920
# Epoch 78/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0056 - accuracy: 0.9979 - val_loss: 0.0373 - val_accuracy: 0.9904
# Epoch 79/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0097 - accuracy: 0.9967 - val_loss: 0.0384 - val_accuracy: 0.9918
# Epoch 80/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0062 - accuracy: 0.9977 - val_loss: 0.0389 - val_accuracy: 0.9919
# Epoch 81/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0058 - accuracy: 0.9979 - val_loss: 0.0390 - val_accuracy: 0.9919
# Epoch 82/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0057 - accuracy: 0.9979 - val_loss: 0.0421 - val_accuracy: 0.9921
# Epoch 83/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0055 - accuracy: 0.9979 - val_loss: 0.0440 - val_accuracy: 0.9921
# Epoch 84/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0056 - accuracy: 0.9979 - val_loss: 0.0401 - val_accuracy: 0.9921
# Epoch 85/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0062 - accuracy: 0.9977 - val_loss: 0.0384 - val_accuracy: 0.9918
# Epoch 86/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0072 - accuracy: 0.9975 - val_loss: 0.0411 - val_accuracy: 0.9918
# Epoch 87/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0063 - accuracy: 0.9977 - val_loss: 0.0454 - val_accuracy: 0.9918
# Epoch 88/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0055 - accuracy: 0.9979 - val_loss: 0.0304 - val_accuracy: 0.9911
# Epoch 89/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.0428 - val_accuracy: 0.9921
# Epoch 90/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0060 - accuracy: 0.9978 - val_loss: 0.0419 - val_accuracy: 0.9919
# Epoch 91/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0052 - accuracy: 0.9980 - val_loss: 0.0419 - val_accuracy: 0.9919
# Epoch 92/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.0390 - val_accuracy: 0.9919
# Epoch 93/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0063 - accuracy: 0.9977 - val_loss: 0.0426 - val_accuracy: 0.9914
# Epoch 94/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.0356 - val_accuracy: 0.9907
# Epoch 95/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0065 - accuracy: 0.9976 - val_loss: 0.0430 - val_accuracy: 0.9919
# Epoch 96/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0064 - accuracy: 0.9977 - val_loss: 0.0449 - val_accuracy: 0.9915
# Epoch 97/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0056 - accuracy: 0.9979 - val_loss: 0.0486 - val_accuracy: 0.9917
# Epoch 98/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0060 - accuracy: 0.9978 - val_loss: 0.0466 - val_accuracy: 0.9917
# Epoch 99/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0059 - accuracy: 0.9978 - val_loss: 0.0408 - val_accuracy: 0.9919
# Epoch 100/100
# 928/928 [==============================] - 27s 29ms/step - loss: 0.0053 - accuracy: 0.9980 - val_loss: 0.0437 - val_accuracy: 0.9912

# %%
#plot the training and validation accuracy and loss at each epoch
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'g', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.vlines(5, 0, 0.14, colors = 'b', linestyles = 'dashed', label='Saved Best Model') # We can see from the training history above that
                                                      # best model was saved at epoch 5
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(linestyle='-')
plt.show()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(epochs, acc, 'g', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.vlines(5, 0.965, 1, colors = 'b', linestyles = 'dashed', label='Saved Best Model') # We can see from the training history above that
                                                      # best model was saved at epoch 5
plt.title('Training and validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(linestyle='-')
plt.show()

# %%
tf.keras.backend.clear_session()
del model
del model2 
del imported_model

# %%
tf.keras.backend.clear_session()
del imported_model
